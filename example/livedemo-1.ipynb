# %%
##%overwritefile
##%file:livedemo/main.py
##%cwd:livedemo
## %noruncode
##%log:1
# -*- coding: utf-8 -*-

from kaki.app import App
from kivy.factory import Factory
from kivymd.uix.floatlayout import MDFloatLayout
from kivymd.uix.tab import MDTabsBase

class Live(App):
    CLASSES = {
        "UI": "live.ui"
    }
    KV_FILES = [".\\live\\ui.kv"]
    AUTORELOADER_PATHS = [
        (".\\live", {"recursive": True}),
    ]
    def __init__(self, **kwargs):
        super(TheLabApp, self).__init__(**kwargs)
        Config.set('graphics', 'resizable', 0)
        Window.size = (600, 800)
    def build_app(self):
        
        return Factory.UI()
    def on_tab_switch(
        self, instance_tabs, instance_tab, instance_tab_label, tab_text
    ):
        '''Called when switching tabs.

        :type instance_tabs: <kivymd.uix.tab.MDTabs object>;
        :param instance_tab: <__main__.Tab object>;
        :param instance_tab_label: <kivymd.uix.tab.MDTabsLabel object>;
        :param tab_text: text or name icon of tab;
        '''

        instance_tab.ids.label.text = tab_text

Live().run()

# %%
##%overwritefile
##%file:livedemo/main.py
##%cwd:livedemo
## %noruncode
##%log:1
# -*- coding: utf-8 -*-
import os
from typing import NoReturn
from kivy.animation import Animation
from kivy.lang import Builder
from kaki.app import App
from kivy.uix.button import Button
from kivy.factory import Factory
from kivy import resources
from kivy.core.text import LabelBase
from kivymd.app import MDApp
from kivymd.uix.picker import MDTimePicker
from kivymd.uix.floatlayout import MDFloatLayout
from kivymd.uix.tab import MDTabsBase
from kivy.config import Config
from kivy.core.window import Window

from kivy.uix.accordion import Accordion, AccordionItem
from ctypes import windll
import pygame

class MainApp(App):

    CLASSES = {
        "UI": "live.ui",
        "Tab": "live.ui"
    }
    KV_FILES = [".\\live\\ui.kv"]
    AUTORELOADER_PATHS = [
        (".\\live", {"recursive": True}),
    ]
    def __init__(self, **kwargs):
        # Window.hide()
        super(MainApp, self).__init__(**kwargs)
    def build_app(self):
        ## 去掉window titlebar
        # Window.borderless = True
        Config.set('graphics', 'resizable', 0)
        # Config.set('graphics', 'position', 'custom')
        # Config.set('graphics', 'left', -1700)
        # Config.set('graphics', 'top', 100)
        pygame.display.
        screen.fill(red)
        pygame.display.update()
        Window.size = (600, 800)
        # Window.show()
        # return Builder.load_string(KV)
        # self.theme_cls.theme_style = "Light"
        self.theme_cls.theme_style = "Dark"
        self.theme_cls.primary_palette = "BlueGray"
        return Factory.UI()
    def on_start(self):
        # Accordion(min_space=160)
        # Accordion(orientation='vertical')
        Window.show()
        # if isWindows():
        # from kivy.config import Config
        ## 禁止鼠标右键大红点，其它解决办法 https://groups.google.com/g/kivy-users/c/CjxO3K0ozeA
        Config.set('input', 'mouse', 'mouse,disable_multitouch')
        # Config.set('kivy', 'window_icon','your_app_icon_64x64.png' )
        Config.set('kivy', 'exit_on_escape', 0)

        pass
    # def on_start(self):
    #     self.fps_monitor_start()
    # def on_start(self):
        # print("self.root  "+str(self.approot.ids))
        # print("self.root len  "+str(len(self.approot.ids)))
        # for key in self.approot.ids:
        #     # if 'live' in key
        #     print("self.root.ids  "+":"+str(key))

        # for i in range(20):
        #     self.approot.ids.tabs.add_widget(Factory.Tab(title=f"Tab {i}"))
    def show_time_picker(self):
        '''Open time picker dialog.'''

        time_dialog = MDTimePicker()
        time_dialog.open()
    def change_rotate(self, instance_button: Button) -> NoReturn:
        Animation(rotate_value_angle=45, d=0.3).start(instance_button)
    def on_tab_switch(
        self, instance_tabs, instance_tab, instance_tab_label, tab_text
    ):
        '''Called when switching tabs.

        :type instance_tabs: <kivymd.uix.tab.MDTabs object>;
        :param instance_tab: <__main__.Tab object>;
        :param instance_tab_label: <kivymd.uix.tab.MDTabsLabel object>;
        :param tab_text: text or name icon of tab;
        '''

        instance_tab.ids.label.text = tab_text
MainApp().run()
